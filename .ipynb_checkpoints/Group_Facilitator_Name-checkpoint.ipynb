# %% [markdown]
# ### Results Expected
# ##### Write all your code in one well-commented Python file; briefly mention the insights and observations from the analysis
#
# Present the overall approach of the analysis in a presentation:
#
# 1. Mention the problem statement and the analysis approach briefly
# 2. Explain the results of univariate, bivariate analysis etc. in business terms
# 3. Include visualisations and summarise the most important results in the presentation

# %% [markdown]
# ### Business Understanding
# ##### Two types of risks are associated with the bank’s decision:
# 1. If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company
# 2. If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company
#
# ##### When a person applies for a loan, there are two types of decisions that could be taken by the company:
# 1. Loan accepted: If the company approves the loan, there are 3 possible scenarios described below:
#
#     a. Fully paid: Applicant has fully paid the loan (the principal and the interest rate)
#
#      b. Current: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
#
#     c. Charged-off: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
#
# 2.Loan rejected: The company had rejected the loan (because the candidate does not meet their requirements etc.). Since the loan was rejected, there is no transactional history of those applicants with the company and so this data is not available with the company (and thus in this dataset)

# %% [markdown]
# # Problem Statement
#
# The aim is to identify patterns which indicate if a person is likely to default, which may be used for taking actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc.
#
# 1. If one is able to identify these risky loan applicants, then such loans can be reduced thereby cutting down the amount of credit loss.
#
# 2. Company wants to understand the driving factors (or driver variables) behind loan default, i.e. the variables which are strong indicators of default.  The company can utilise this knowledge for its portfolio and risk assessment.

# %% [markdown]
# ![loan-classification](Loan_image.png)

# %% [markdown]
# # Analysis Approach:
#
# ## 1. Technical Approach:
#
# ### A. Decomposition:
# * Define Target Variable.
# * Remove inconsistent rows and columns.
# * Remove outliers.
# * Transform values
# * Univariate analysis and all columns to understand value distribution.
# * Bivariate analysis on target variable and each column to define feature variable.
# * Multivariate analysis to detect no relation present between feature variables.
# * Study relation between feature variable and target variables.
#
# ### B. Pattern recognition:
# * Study feature variables behaviour.
# * Study relation between target variable and feature variables.
#
# ### C. Abstraction:
# * Feature selection on the basis of target value distributions.
#
# ### D. Algorithms:
# * Create pipeline for Data Understanding, Data Transformation, Data Analysis, and Data Selection.
#
# ## 2. Business Approach
#
# ### A. Detection
# * Find Target.
# * Detect features affecting target.
# * Analyse change in target outcome with variations in features.
#
# ### B. Knowledge:
# * Measure that should be on features.
# * Additional information that should be collected to predict better target outcome.

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set options
# pandas
pd.set_option('display.width', None,'display.max_colwidth', None,'display.max_rows',None)
# plot charts
# %matplotlib inline
sns.set(color_codes=True)

# %%
# READ COLUMNS
df=pd.read_csv('loan.csv')
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_9360\3502384094.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('loan.csv')

# %%
# READ COLUMNS DESCRIPTIONS
df_columns=pd.read_csv('loan_columns.csv')
df_columns.head()
# Out:
#                  column  \
# 0        acc_now_delinq
# 1  acc_open_past_24mths
# 2            addr_state
# 3              all_util
# 4            annual_inc
#
#                                                               column_description
# 0                The number of accounts on which the borrower is now delinquent.
# 1                                     Number of trades opened in past 24 months.
# 2                     The state provided by the borrower in the loan application
# 3                                          Balance to credit limit on all trades
# 4  The self-reported annual income provided by the borrower during registration.

# %% [markdown]
# # Data understanding

# %% [markdown]
# ## Information

# %%
pd.set_option('display.max_columns', None)
df.head(1)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
#
#    annual_inc verification_status issue_d loan_status pymnt_plan  \
# 0     24000.0            Verified  Dec-11  Fully Paid          n
#
#                                                                 url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
#
#                                                                              desc  \
# 0    Borrower added on 12/22/11 > I need to upgrade my business technologies.<br>
#
#        purpose     title zip_code addr_state    dti  delinq_2yrs  \
# 0  credit_card  Computer    860xx         AZ  27.65            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# ...

# %%
# description about dataframe columns
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
# information about dataframe
df.info(verbose=True,memory_usage=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Non-Null Count  Dtype
# ---   ------                          --------------  -----
#  0    id                              39717 non-null  int64
#  1    member_id                       39717 non-null  int64
#  2    loan_amnt                       39717 non-null  int64
#  3    funded_amnt                     39717 non-null  int64
#  4    funded_amnt_inv                 39717 non-null  float64
#  5    term                            39717 non-null  object
#  6    int_rate                        39717 non-null  object
#  7    installment                     39717 non-null  float64
#  8    grade                           39717 non-null  object
#  9    sub_grade                       39717 non-null  object
#  10   emp_title                       37258 non-null  object
#  11   emp_length                      38642 non-null  object
# ...

# %%
# shape and size of dataframes
df.shape,df.size
print(f"""
rows: {df.shape[0]}
columns: {df.shape[1]}
""")
# Out:
# rows: 39717
# columns: 111

# %%
# column distribution
df_columns
# Out:
#                              column  \
# 0                    acc_now_delinq
# 1              acc_open_past_24mths
# 2                        addr_state
# 3                          all_util
# 4                        annual_inc
# 5                  annual_inc_joint
# 6                  application_type
# 7                       avg_cur_bal
# 8                    bc_open_to_buy
# 9                           bc_util
# 10         chargeoff_within_12_mths
# 11          collection_recovery_fee
# 12       collections_12_mths_ex_med
# 13                      delinq_2yrs
# 14                      delinq_amnt
# 15                             desc
# 16                              dti
# 17                        dti_joint
# 18                 earliest_cr_line
# 19                       emp_length
# 20                        emp_title
# 21                  fico_range_high
# 22                   fico_range_low
# 23                      funded_amnt
# 24                  funded_amnt_inv
# ...

# %% [markdown]
# ## Target Variable:
# ***
# **loan Status: loan_status**

# %%
df_columns[df_columns['column']=='loan_status']
# Out:
#          column          column_description
# 42  loan_status  Current status of the loan

# %%
# target value distribution
df['loan_status'].value_counts(normalize=True)*100
# Out:
# Fully Paid     82.961956
# Charged Off    14.167737
# Current         2.870307
# Name: loan_status, dtype: float64

# %% [markdown]
# **Values to be considered for analysis:**
# * Fully Paid
# * Charged Off

# %%
# target value distribution plot
df['loan_status'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ### Null Values

# %% [markdown]
# ##### Operation:
# * Remove columns with more than 30% null values.

# %%
# null values percentage in columns
(df.isnull().sum()/df.shape[0])*100
# Out:
# id                                  0.000000
# member_id                           0.000000
# loan_amnt                           0.000000
# funded_amnt                         0.000000
# funded_amnt_inv                     0.000000
# term                                0.000000
# int_rate                            0.000000
# installment                         0.000000
# grade                               0.000000
# sub_grade                           0.000000
# emp_title                           6.191303
# emp_length                          2.706650
# home_ownership                      0.000000
# annual_inc                          0.000000
# verification_status                 0.000000
# issue_d                             0.000000
# loan_status                         0.000000
# pymnt_plan                          0.000000
# url                                 0.000000
# desc                               32.580507
# purpose                             0.000000
# ...

# %%
# null values percentage in columns
((df.isnull().sum()/df.shape[0])*100).plot(kind='bar',figsize=(30,5))
plt.show()

# %%
# columns having more than 30% null values
null_columns_30 = df.columns[(df.isnull().sum()/df.shape[0])*100 > 30.0]
print("total columns to be rejected (having more than 30% null values):",len(null_columns_30))
# Out:
# total columns to be rejected (having more than 30% null values): 58

# %% [markdown]
# **removing columns with null values percentage > 30%**

# %%
# updating the same datafranme by dropping rejected columns
df=df.drop(columns=null_columns_30)

# %%
# updated null values percentage in columns
((df.isnull().sum()/df.shape[0])*100).plot(kind='bar',figsize=(30,5))
plt.show()

# %%
# new shape and size of updated dataframe
print(f"rows:{df.shape[0]}  | columns:{df.shape[1]}")
df.head(1)
# Out:
# rows:39717  | columns:53
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
#
#    annual_inc verification_status issue_d loan_status pymnt_plan  \
# 0     24000.0            Verified  Dec-11  Fully Paid          n
#
#                                                                 url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
#
#        purpose     title zip_code addr_state    dti  delinq_2yrs  \
# 0  credit_card  Computer    860xx         AZ  27.65            0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0           Jan-85               1         3        0      13648     83.70%
#
# ...

# %% [markdown]
# **Divide columns based on their values data types**

# %%
# finding continuos and categorical variables
int_float_variables=[column for column in df.columns if df[column].dtype in ['int64','float64']] # integers and floats
object_variables=[column for column in df.columns if df[column].dtype=='object'] # objects

print(f"""
numerical variables: {len(int_float_variables)}
object variables: {len(object_variables)}
""")
# Out:
# numerical variables: 31
# object variables: 22

# %% [markdown]
# ### Numerical variables:

# %%
# total number of continuous variables
print("total numerical variables counts:",len(int_float_variables))
# Out:
# total numerical variables counts: 31

# %%
# histogram plot for continuos variables
df.loc[:,int_float_variables].hist(figsize=(25,10),layout=(4,8))
plt.show()

# %% [markdown]
# ##### Notes:
# 1. most of the columns have only zero as value.
# 2. some column have only single value.

# %%
# find columns with single value ('0' or other).
singlevalue_columns=[column for column in df.loc[:,int_float_variables].columns if len(df[column].value_counts().index)==1]
print("columns with single value:",singlevalue_columns)
# Out:
# columns with single value: ['collections_12_mths_ex_med', 'policy_code', 'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'tax_liens']

# %%
# drop columns with only single values
df=df.drop(columns=singlevalue_columns)

# %%
# update int-float variable list
int_float_variables=[column for column in int_float_variables if column not in singlevalue_columns]
print(f"numerical value columns: {len(int_float_variables)}")
# Out:
# numerical value columns: 25

# %%
# updated dataframe
df.head(1)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
#
#    annual_inc verification_status issue_d loan_status pymnt_plan  \
# 0     24000.0            Verified  Dec-11  Fully Paid          n
#
#                                                                 url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
#
#        purpose     title zip_code addr_state    dti  delinq_2yrs  \
# 0  credit_card  Computer    860xx         AZ  27.65            0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0           Jan-85               1         3        0      13648     83.70%
#
#    total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# ...

# %%
# new shape and size of dataframe
print(f"rows:{df.shape[0]}  | columns:{df.shape[1]}")
# Out:
# rows:39717  | columns:47

# %%
# histogram plot for continuos variables
df.loc[:,int_float_variables].hist(figsize=(20,20),layout=(5,5),bins=20)
plt.show()

# %% [markdown]
# ### Object Variables

# %%
# total object variables
print("total object variables columns:", len(object_variables))
# Out:
# total object variables columns: 22

# %% [markdown]
# ##### Notes:
#  * Some columns may have only one value type

# %%
# find columns with single value count.
singlevalue_categ_columns=[column for column in df.loc[:,object_variables].columns if len(df[column].value_counts().index)==1]
print("object columns with single value:",singlevalue_categ_columns)
# Out:
# object columns with single value: ['pymnt_plan', 'initial_list_status', 'application_type']

# %%
# drop columns with only single values
df=df.drop(columns=singlevalue_categ_columns)

# %%
# updated dataframe
df.head(1)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
#
#   int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0   10.65%       162.87     B        B2       NaN  10+ years           RENT
#
#    annual_inc verification_status issue_d loan_status  \
# 0     24000.0            Verified  Dec-11  Fully Paid
#
#                                                                 url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
#
#        purpose     title zip_code addr_state    dti  delinq_2yrs  \
# 0  credit_card  Computer    860xx         AZ  27.65            0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0           Jan-85               1         3        0      13648     83.70%
#
#    total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# ...

# %%
# new shape and size of dataframe
print(f"rows:{df.shape[0]}  | columns:{df.shape[1]}")
# Out:
# rows:39717  | columns:44

# %%
# update object variable list
object_variables=[column for column in object_variables if column not in singlevalue_categ_columns]
# updated categorical variables
print("object variables:", len(object_variables)," -- ","\n",list(object_variables))
# Out:
# object variables: 19  --
#  ['term', 'int_rate', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 'loan_status', 'url', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'revol_util', 'last_pymnt_d', 'last_credit_pull_d']

# %%
# object variables segmentaion --> less or more than 10 values counts
object_variables_less_10values=[column for column in object_variables if len(df[column].value_counts().index)<=10]
object_variables_more_10values=[column for column in object_variables if len(df[column].value_counts().index)>10]

print(f"""object data types columns, for value counts --->
less than or 10 values, (may be discrete) : {len(object_variables_less_10values)}
more than 10 values : {len(object_variables_more_10values)}
""")
# Out:
# object data types columns, for value counts --->
# less than or 10 values, (may be discrete) : 5
# more than 10 values : 14

# %% [markdown]
# ###### function to plot categorical columns plot

# %%
# create function to plot categorical columns plot --> frequency plot and show information
'''
if number of values less than or equal to 10, plot horizontal bar chart
else if number of values less than or equal to 100, plot pie chart
else, if number of values more than 100, display information.
'''

def object_column_plot(column_name):
    '''plot for columns'''
    # if values count less than or equal to 10
    if len(df[column_name].value_counts().index)<=10:
        df[column_name].value_counts().plot(kind='barh',title=column_name,figsize=(20,5))
        plt.show()
        # if only one value type is in column
        if len(df[column_name].value_counts().index)==1:
            print(" -- only one value type -- ")
    # if value count more than 10 but less than 100
    elif len(df[column_name].value_counts().index)<=100:
            df[column_name].value_counts().plot(kind='pie')
            plt.show()
            print(f"""
            value counts -- {len(df[column_name].value_counts().index)}
            """)
    # if value count exceeds 100
    else:
        print(f"""
        value counts -- {len(df[column_name].value_counts().index)}
        values(top 5) -- {list(df[column_name].value_counts().index[:5])}
        """)

# %% [markdown]
# **understanding of categorical variables with less than or equals to 10 values counts**

# %%
# categorical values with less than or 10 value types
print("categorical values with less than or 10 value counts:",len(object_variables_less_10values),"--","\n",list(object_variables_less_10values))
# Out:
# categorical values with less than or 10 value counts: 5 --
#  ['term', 'grade', 'home_ownership', 'verification_status', 'loan_status']

# %%
# term
object_column_plot('term')

# %% [markdown]
# ##### Notes:
# * Column can be converted to integer columns.
# * Discrete variable.

# %%
# grade
object_column_plot('grade')

# %% [markdown]
# ##### Notes:
# * Discrete variable.

# %%
# home ownership
object_column_plot('home_ownership')

# %% [markdown]
# ##### Notes:
# * Discrete variable.

# %%
# verfication status
object_column_plot('verification_status')

# %% [markdown]
# ##### Notes:
# * Discrete variable.

# %%
# loan status
object_column_plot('loan_status')

# %% [markdown]
# ##### Notes:
# * Discrete variable.

# %% [markdown]
# **understanding of categorical variables with more than 10 value counts**

# %%
# columns with more than 10 value counts
print("object values with more than 10 value counts:",len(object_variables_more_10values)," -- ", "\n", list(object_variables_more_10values))
# Out:
# object values with more than 10 value counts: 14  --
#  ['int_rate', 'sub_grade', 'emp_title', 'emp_length', 'issue_d', 'url', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'revol_util', 'last_pymnt_d', 'last_credit_pull_d']

# %%
# interest rate
object_column_plot('int_rate')
# Out:
#         value counts -- 371
#         values(top 5) -- ['10.99%', '13.49%', '11.49%', '7.51%', '7.88%']

# %% [markdown]
# ##### Notes:
# * Columns can be converted to float data type.
# * Numerical variable.

# %%
# sub grades
object_column_plot('sub_grade')
# Out:
#             value counts -- 35

# %%
# employee title
object_column_plot('emp_title')
# Out:
#         value counts -- 28820
#         values(top 5) -- ['US Army', 'Bank of America', 'IBM', 'AT&T', 'Kaiser Permanente']

# %%
# employee length
object_column_plot('emp_length')
# Out:
#             value counts -- 11

# %% [markdown]
# ##### Notes:
# * Column can be converted to float data type.
# * Discrete variable.

# %%
# issue date
object_column_plot('issue_d')
# Out:
#             value counts -- 55

# %% [markdown]
# ##### Notes:
# * Column can be converted to date data type.
# * Discrete variable.

# %%
# url address
object_column_plot('url')
# Out:
#         value counts -- 39717
#         values(top 5) -- ['https://lendingclub.com/browse/loanDetail.action?loan_id=1077501', 'https://lendingclub.com/browse/loanDetail.action?loan_id=568534', 'https://lendingclub.com/browse/loanDetail.action?loan_id=568659', 'https://lendingclub.com/browse/loanDetail.action?loan_id=567165', 'https://lendingclub.com/browse/loanDetail.action?loan_id=568531']

# %%
# loan purpose
object_column_plot('purpose')
# Out:
#             value counts -- 14

# %%
# loan title
object_column_plot('title')
# Out:
#         value counts -- 19615
#         values(top 5) -- ['Debt Consolidation', 'Debt Consolidation Loan', 'Personal Loan', 'Consolidation', 'debt consolidation']

# %%
# zip codes
object_column_plot('zip_code')
# Out:
#         value counts -- 823
#         values(top 5) -- ['100xx', '945xx', '112xx', '606xx', '070xx']

# %%
# address states
object_column_plot('addr_state')
# Out:
#             value counts -- 50

# %%
# earliest credit line
object_column_plot('earliest_cr_line')
# Out:
#         value counts -- 526
#         values(top 5) -- ['Nov-98', 'Oct-99', 'Dec-98', 'Oct-00', 'Dec-97']

# %%
# revolving utilization
object_column_plot('revol_util')
# Out:
#         value counts -- 1089
#         values(top 5) -- ['0%', '0.20%', '63%', '40.70%', '66.70%']

# %%
# last payment date
object_column_plot('last_pymnt_d')
# Out:
#         value counts -- 101
#         values(top 5) -- ['May-16', 'Mar-13', 'Dec-14', 'May-13', 'Feb-13']

# %%
# last credit pulled
object_column_plot('last_credit_pull_d')
# Out:
#         value counts -- 106
#         values(top 5) -- ['May-16', 'Apr-16', 'Mar-16', 'Feb-13', 'Feb-16']

# %% [markdown]
# ##### Notes:
# * some object columns can be converted to integer/float columns.
# * some object columns can be converted to date-time columns.
# * columns purpose and type have similar values.
# * some columns like can be dropped off.

# %% [markdown]
# ### Not Available Values

# %% [markdown]
# ##### Operation:
# * Remove columns with more than 30% not available values.

# %%
# not available values percentage in columns
(df.isna().sum()/df.shape[0])*100
# Out:
# id                         0.000000
# member_id                  0.000000
# loan_amnt                  0.000000
# funded_amnt                0.000000
# funded_amnt_inv            0.000000
# term                       0.000000
# int_rate                   0.000000
# installment                0.000000
# grade                      0.000000
# sub_grade                  0.000000
# emp_title                  6.191303
# emp_length                 2.706650
# home_ownership             0.000000
# annual_inc                 0.000000
# verification_status        0.000000
# issue_d                    0.000000
# loan_status                0.000000
# url                        0.000000
# purpose                    0.000000
# title                      0.027696
# zip_code                   0.000000
# addr_state                 0.000000
# dti                        0.000000
# delinq_2yrs                0.000000
# earliest_cr_line           0.000000
# inq_last_6mths             0.000000
# ...

# %%
# not available percentage in columns
((df.isnull().sum()/df.shape[0])*100).plot(kind='bar',figsize=(30,5))
plt.show()

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ### Missing Values Operations

# %% [markdown]
# #### Null values

# %%
import missingno as msno

# %%
msno.matrix(df)
plt.show()

# %%
msno.bar(df)
plt.show()

# %%
msno.heatmap(df)
plt.show()

# %%
# detect columns with null values and find percentage of null values
print(f"columns with null values: {len(list(df.columns[df.isnull().any()]))}")
((df[df.columns[df.isnull().any()]].isnull().sum()/df.shape[0])*100).plot(kind='barh')
plt.show()
# Out:
# columns with null values: 7

# %% [markdown]
# search missing values in column and check other relavant value count information

# %%
def missing_value_search(column_name):
    print(f"""
    missing values percentage -- {round(((df[column_name].isna().sum()/df.shape[0])*100),2)}%
    total value counts -- {len(df[column_name].value_counts().index)}
    values(top 5) -- {sorted(list(df[column_name].value_counts().index[:5]))}
    """)

# %% [markdown]
# fill missing values in column

# %%
# '-1' for integer/float dtypes, 'NA' for objects, '0' for datetime
def fill_mising_values(column_name,value=-1):
    df[column_name].fillna(value=value,inplace=True)
    print("Null Values Status in",column_name,"column : ",df[column_name].isnull().any())
    print("Not available Values Status in",column_name,"column : ",df[column_name].isna().any())

# %% [markdown]
# **Find and Fill null values in columns**

# %%
# employee title
missing_value_search('emp_title')
# Out:
#     missing values percentage -- 6.19%
#     total value counts -- 28820
#     values(top 5) -- ['AT&T', 'Bank of America', 'IBM', 'Kaiser Permanente', 'US Army']

# %% [markdown]
# ##### Notes:
# * Replace null values with 'NA'.

# %%
fill_mising_values('emp_title',value='NA')
# Out:
# Null Values Status in emp_title column :  False
# Not available Values Status in emp_title column :  False

# %%
# employee length
missing_value_search('emp_length')
# Out:
#     missing values percentage -- 2.71%
#     total value counts -- 11
#     values(top 5) -- ['10+ years', '2 years', '3 years', '4 years', '< 1 year']

# %% [markdown]
# ##### Notes:
# * Replace null values with '-1'.

# %%
fill_mising_values('emp_length',value=-1)
# Out:
# Null Values Status in emp_length column :  False
# Not available Values Status in emp_length column :  False

# %%
# loan title
missing_value_search('title')
# Out:
#     missing values percentage -- 0.03%
#     total value counts -- 19615
#     values(top 5) -- ['Consolidation', 'Debt Consolidation', 'Debt Consolidation Loan', 'Personal Loan', 'debt consolidation']

# %% [markdown]
# ##### Notes:
# * Replace missing values with 'NA'.

# %%
fill_mising_values('title',value='NA')
# Out:
# Null Values Status in title column :  False
# Not available Values Status in title column :  False

# %%
# revolution utilities
missing_value_search('revol_util')
# Out:
#     missing values percentage -- 0.13%
#     total value counts -- 1089
#     values(top 5) -- ['0%', '0.20%', '40.70%', '63%', '66.70%']

# %% [markdown]
# ##### Notes:
# * Replace null values with '-1'.

# %%
fill_mising_values('revol_util',value=-1)
# Out:
# Null Values Status in revol_util column :  False
# Not available Values Status in revol_util column :  False

# %%
# last payment date
missing_value_search('last_pymnt_d')
# Out:
#     missing values percentage -- 0.18%
#     total value counts -- 101
#     values(top 5) -- ['Dec-14', 'Feb-13', 'Mar-13', 'May-13', 'May-16']

# %% [markdown]
# ##### Notes:
# * Replace null values with '0'.

# %%
fill_mising_values('last_pymnt_d',value=0)
# Out:
# Null Values Status in last_pymnt_d column :  False
# Not available Values Status in last_pymnt_d column :  False

# %%
# last credit pulled date
missing_value_search('last_credit_pull_d')
# Out:
#     missing values percentage -- 0.01%
#     total value counts -- 106
#     values(top 5) -- ['Apr-16', 'Feb-13', 'Feb-16', 'Mar-16', 'May-16']

# %% [markdown]
# ##### Notes:
# * Replace null values with '0'.

# %%
fill_mising_values('last_credit_pull_d',value=0)
# Out:
# Null Values Status in last_credit_pull_d column :  False
# Not available Values Status in last_credit_pull_d column :  False

# %%
# publicly record bannkruptcies
missing_value_search('pub_rec_bankruptcies')
# Out:
#     missing values percentage -- 1.75%
#     total value counts -- 3
#     values(top 5) -- [0.0, 1.0, 2.0]

# %%
fill_mising_values('pub_rec_bankruptcies',value=-1)
# Out:
# Null Values Status in pub_rec_bankruptcies column :  False
# Not available Values Status in pub_rec_bankruptcies column :  False

# %% [markdown]
# ### Data Type Conversion

# %% [markdown]
# ##### Integer and Float data type variables

# %% [markdown]
# ##### Notes:
# * if required, values can be scaled.

# %% [markdown]
# ##### Object data type variables

# %%
# total columns
print(f"object columns: {len(object_variables)}")
# Out:
# object columns: 19

# %%
# check object variables dataframe
pd.DataFrame({column:df[column].value_counts().index[:2] for column in df.loc[:,object_variables].columns})
# Out:
#          term int_rate grade sub_grade emp_title emp_length home_ownership  \
# 0   36 months   10.99%     B        B3        NA  10+ years           RENT
# 1   60 months   13.49%     A        A4   US Army   < 1 year       MORTGAGE
#
#   verification_status issue_d  loan_status  \
# 0        Not Verified  Dec-11   Fully Paid
# 1            Verified  Nov-11  Charged Off
#
#                                                                 url  \
# 0  https://lendingclub.com/browse/loanDetail.action?loan_id=1077501
# 1   https://lendingclub.com/browse/loanDetail.action?loan_id=568534
#
#               purpose                    title zip_code addr_state  \
# 0  debt_consolidation       Debt Consolidation    100xx         CA
# 1         credit_card  Debt Consolidation Loan    945xx         NY
#
#   earliest_cr_line revol_util last_pymnt_d last_credit_pull_d
# 0           Nov-98         0%       May-16             May-16
# 1           Oct-99      0.20%       Mar-13             Apr-16

# %% [markdown]
# **Columns to be transformed:**
# * term
# * int_rate
# * emp_length
# * issue_d
# * zip_code
# * earliest_cr_line
# * revol_util
# * last_pymnt_d
# * last_credit_pull_d

# %%
# term
df['term'].value_counts().index
# Out:
# Index([' 36 months', ' 60 months'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- integer
# * variable type -- discrete

# %%
df['term']=df['term'].apply(lambda x: int(x[1:3]))
df['term'].value_counts().index
# Out:
# Int64Index([36, 60], dtype='int64')

# %%
# interest rate
df['int_rate'].value_counts().index[:5]
# Out:
# Index(['10.99%', '13.49%', '11.49%', '7.51%', '7.88%'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- float
# * variable type -- continuos

# %%
df['int_rate']=df['int_rate'].apply(lambda x: float(x[:-1]))
df['int_rate'].value_counts().index[:5]
# Out:
# Float64Index([10.99, 13.49, 11.49, 7.51, 7.88], dtype='float64')

# %%
# employement length
df['emp_length'].value_counts().index[:5]
# Out:
# Index(['10+ years', '< 1 year', '2 years', '3 years', '4 years'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- integer
# * variable type -- discrete

# %%
# for 10+ years -- keep 10
# for <1 years -- keep 0
df['emp_length']=df['emp_length'].apply(lambda x: 10 if x=="10+ years" else 0 if x=="< 1 year" else int(x.split(" ")[0]) if x!=-1 else x)
df['emp_length'].value_counts().index
# Out:
# Int64Index([10, 0, 2, 3, 4, 5, 1, 6, 7, 8, 9, -1], dtype='int64')

# %%
# revolution utilities
df['revol_util'].value_counts().index[:5]
# Out:
# Index(['0%', '0.20%', '63%', '0.10%', '66.70%'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- float
# * variable type -- continuos

# %%
df['revol_util']=df['revol_util'].apply(lambda x: float(x[:-1]) if x!=-1 else x)
df['revol_util'].value_counts().index[:10]
# Out:
# Float64Index([0.0, 0.2, 63.0, 0.1, 66.7, 40.7, 31.2, 46.4, 66.6, 61.0], dtype='float64')

# %%
# issue date
df['issue_d'].value_counts().index[:3]
# Out:
# Index(['Dec-11', 'Nov-11', 'Oct-11'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- datetime
# * variable type -- discrete

# %%
df['issue_d']=pd.to_datetime(df['issue_d'],format="%b-%y")
df['issue_d'].value_counts().index[:3]
# Out:
# DatetimeIndex(['2011-12-01', '2011-11-01', '2011-10-01'], dtype='datetime64[ns]', freq=None)

# %%
# zipcode
df['zip_code'].value_counts().index[:3]
# Out:
# Index(['100xx', '945xx', '112xx'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- integers
# * variable type -- discrete

# %%
df['zip_code']=df['zip_code'].apply(lambda x: int(x[:3]))
df['zip_code'].value_counts().index[:3]
# Out:
# Int64Index([100, 945, 112], dtype='int64')

# %%
# earlier credit line date
df['earliest_cr_line'].value_counts().index[:3]
# Out:
# Index(['Nov-98', 'Oct-99', 'Dec-98'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- datetime
# * variable type -- discrete

# %%
df['earliest_cr_line']=pd.to_datetime(df['earliest_cr_line'],format="%b-%y")
df['earliest_cr_line'].value_counts().index[:3]
# Out:
# DatetimeIndex(['1998-11-01', '1999-10-01', '1998-12-01'], dtype='datetime64[ns]', freq=None)

# %%
# last payment date
df['last_pymnt_d'].value_counts().index[:3]
# Out:
# Index(['May-16', 'Mar-13', 'Dec-14'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- datetime
# * variable type -- discrete

# %%
df['last_pymnt_d']=pd.to_datetime(df['last_pymnt_d'][df['last_pymnt_d']!=0],format="%b-%y")
df['last_pymnt_d'].value_counts().index[:3]
# Out:
# DatetimeIndex(['2016-05-01', '2013-03-01', '2014-12-01'], dtype='datetime64[ns]', freq=None)

# %%
# last credit pull date
df['last_credit_pull_d'].value_counts().index[:3]
# Out:
# Index(['May-16', 'Apr-16', 'Mar-16'], dtype='object')

# %% [markdown]
# ##### Notes:
# * Transformation needed.
# * convert into datatype -- datetime
# * variable type -- discrete

# %%
df['last_credit_pull_d']=pd.to_datetime(df['last_credit_pull_d'][df['last_credit_pull_d']!=0],format="%b-%y")
df['last_credit_pull_d'].value_counts().index[:3]
# Out:
# DatetimeIndex(['2016-05-01', '2016-04-01', '2016-03-01'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Inconsistent Variables

# %% [markdown]
# * Remove columns having no affect on the outcome.
# * These are the columns having no significant role in decision making.
# * Additional datainserted in dataframe.

# %%
# columns and value counts
{column:(df[column].value_counts().index[0],df[column].dtype,f"value-counts({len(df[column].value_counts().index)})") for column in df.columns}
# Out:
# {'id': (1077501, dtype('int64'), 'value-counts(39717)'),
#  'member_id': (1296599, dtype('int64'), 'value-counts(39717)'),
#  'loan_amnt': (10000, dtype('int64'), 'value-counts(885)'),
#  'funded_amnt': (10000, dtype('int64'), 'value-counts(1041)'),
#  'funded_amnt_inv': (5000.0, dtype('float64'), 'value-counts(8205)'),
#  'term': (36, dtype('int64'), 'value-counts(2)'),
#  'int_rate': (10.99, dtype('float64'), 'value-counts(371)'),
#  'installment': (311.11, dtype('float64'), 'value-counts(15383)'),
#  'grade': ('B', dtype('O'), 'value-counts(7)'),
#  'sub_grade': ('B3', dtype('O'), 'value-counts(35)'),
#  'emp_title': ('NA', dtype('O'), 'value-counts(28821)'),
#  'emp_length': (10, dtype('int64'), 'value-counts(12)'),
#  'home_ownership': ('RENT', dtype('O'), 'value-counts(5)'),
#  'annual_inc': (60000.0, dtype('float64'), 'value-counts(5318)'),
#  'verification_status': ('Not Verified', dtype('O'), 'value-counts(3)'),
#  'issue_d': (Timestamp('2011-12-01 00:00:00'),
# ...

# %%
# columns descriptions
df_columns[df_columns['column'].isin(df.columns)]
# Out:
#                       column  \
# 2                 addr_state
# 4                 annual_inc
# 11   collection_recovery_fee
# 13               delinq_2yrs
# 16                       dti
# 18          earliest_cr_line
# 19                emp_length
# 20                 emp_title
# 23               funded_amnt
# 24           funded_amnt_inv
# 25                     grade
# 26            home_ownership
# 27                        id
# 32            inq_last_6mths
# 33               installment
# 34                  int_rate
# 35                   issue_d
# 36        last_credit_pull_d
# 39           last_pymnt_amnt
# 40              last_pymnt_d
# 41                 loan_amnt
# 42               loan_status
# 44                 member_id
# 73                  open_acc
# 80                 out_prncp
# 81             out_prncp_inv
# 85                   pub_rec
# 86      pub_rec_bankruptcies
# 87                   purpose
# 89                recoveries
# 90                 revol_bal
# ...

# %%
# dataframe
df.head(3)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
# 2  1077175    1313524       2400         2400           2400.0    36
#
#    int_rate  installment grade sub_grade emp_title  emp_length home_ownership  \
# 0     10.65       162.87     B        B2        NA          10           RENT
# 1     15.27        59.83     C        C4     Ryder           0           RENT
# 2     15.96        84.33     C        C5        NA          10           RENT
#
#    annual_inc verification_status    issue_d  loan_status  \
# 0     24000.0            Verified 2011-12-01   Fully Paid
# 1     30000.0     Source Verified 2011-12-01  Charged Off
# 2     12252.0        Not Verified 2011-12-01   Fully Paid
#
#                                                                 url  \
# ...

# %% [markdown]
# ##### Notes:
# * remove some columns which have no effect
# * 'id' , 'member_id' -- user details
# * 'funded_amnt_inv', 'sub_grade', 'emp_title', 'url', 'out_prncp', 'out_prncp_inv', 'title', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d' -- irrelevant

# %%
# inconsistent columns
inconsitent_columns=['id','member_id','funded_amnt','funded_amnt_inv','sub_grade','emp_title','url','out_prncp','out_prncp_inv','title','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_amnt','last_pymnt_d']

# %%
# drop inconsistent columns and update dataframe
df=df.drop(columns=inconsitent_columns)

# %%
# updated dataframe
df.head(1)
# Out:
#    loan_amnt  term  int_rate  installment grade  emp_length home_ownership  \
# 0       5000    36     10.65       162.87     B          10           RENT
#
#    annual_inc verification_status    issue_d loan_status      purpose  \
# 0     24000.0            Verified 2011-12-01  Fully Paid  credit_card
#
#    zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0       860         AZ  27.65            0       1985-01-01               1
#
#    open_acc  pub_rec  revol_bal  revol_util  total_acc last_credit_pull_d  \
# 0         3        0      13648        83.7          9         2016-05-01
#
#    pub_rec_bankruptcies
# 0                   0.0

# %%
# new shape and size of dataframe
print(f"rows:{df.shape[0]}  | columns:{df.shape[1]}")
# Out:
# rows:39717  | columns:25

# %% [markdown]
# # Data analysis

# %%
# target variable
df_columns[df_columns['column']=='loan_status']
# Out:
#          column          column_description
# 42  loan_status  Current status of the loan

# %%
# graph plot for 'loan status' column
df['loan_status'].value_counts().plot(kind='barh')
plt.show()

# %%
# we need to check success and failures, thus no need for rows having 'Current' value in 'loan status' column
# update dataframe
df=df[df['loan_status']!='Current']
print(f"rows:{df.shape[0]}  | columns:{df.shape[1]}")
# Out:
# rows:38577  | columns:25

# %%
df['loan_status'].value_counts(normalize=True)*100
# Out:
# Fully Paid     85.413588
# Charged Off    14.586412
# Name: loan_status, dtype: float64

# %% [markdown]
# **Percentage of users Charged off: 14.48%**

# %%
# plot for 'loan status' column
df['loan_status'].value_counts().plot(kind='barh')
plt.show()

# %%
# analysisng dataframe with 'loan status' column values as "-charged off-"
df[df['loan_status']=='Charged Off'].head()
# Out:
#     loan_amnt  term  int_rate  installment grade  emp_length home_ownership  \
# 1        2500    60     15.27        59.83     C           0           RENT
# 8        5600    60     21.28       152.39     F           4            OWN
# 9        5375    60     12.69       121.45     B           0           RENT
# 12       9000    36     13.49       305.38     C           0           RENT
# 14      10000    36     10.65       325.74     B           3           RENT
#
#     annual_inc verification_status    issue_d  loan_status  \
# 1      30000.0     Source Verified 2011-12-01  Charged Off
# 8      40000.0     Source Verified 2011-12-01  Charged Off
# 9      15000.0            Verified 2011-12-01  Charged Off
# 12     30000.0     Source Verified 2011-12-01  Charged Off
# 14    100000.0     Source Verified 2011-12-01  Charged Off
#
#                purpose  zip_code addr_state    dti  delinq_2yrs  \
# 1                  car       309         GA   1.00            0
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# find mean, median and mode

# %%
def column_statistics(column_name):
    print(f"""
mean: {round(df[column_name].mean(),2)}
median: {round(df[column_name].median(),2)}
mode: {df[column_name].value_counts().index[0]}
""")

# %% [markdown]
# remove outliers

# %%
def remove_outliers(column_name):
    global df
    Q1=df[column_name].quantile(0.25)
    Q3=df[column_name].quantile(0.75)
    IQR=Q3-Q1
#     update dataframe
    df = df[~((df[column_name] < (Q1 - 1.5 * IQR)) |(df[column_name] > (Q3 + 1.5 * IQR)))]
    df[column_name].plot(kind='box',vert=False,figsize=(30,10))
    plt.show()

# %%
# available columns, except target columns 'loan status'
print(f"""
columns: {len(df.loc[:,df.columns!='loan_status'].columns)}
{list(df.loc[:,df.columns!='loan_status'].columns)}
""")
# Out:
# columns: 24
# ['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'purpose', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'last_credit_pull_d', 'pub_rec_bankruptcies']

# %%
# kurtosis values for all columns, except target columns 'loan status'
df.loc[:,df.columns!='loan_status'].kurt()
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_9360\2395972127.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[:,df.columns!='loan_status'].kurt()
# loan_amnt                  0.842952
# term                      -0.605196
# int_rate                  -0.447280
# installment                1.317998
# emp_length                -1.321497
# annual_inc              2308.775186
# zip_code                  -1.541214
# dti                       -0.856298
# delinq_2yrs               39.727336
# inq_last_6mths             2.524438
# open_acc                   1.693960
# pub_rec                   23.750596
# revol_bal                 15.048867
# revol_util                -1.109012
# total_acc                  0.700523
# pub_rec_bankruptcies      13.521473
# dtype: float64

# %%
# skew values for all columns, except target columns 'loan status'
df.loc[:,df.columns!='loan_status'].skew()
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_9360\4060386874.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[:,df.columns!='loan_status'].skew()
# loan_amnt                1.078103
# term                     1.181032
# int_rate                 0.293627
# installment              1.150486
# emp_length               0.208808
# annual_inc              31.198414
# zip_code                 0.080938
# dti                     -0.026842
# delinq_2yrs              5.033279
# inq_last_6mths           1.384390
# open_acc                 1.007288
# pub_rec                  4.519991
# revol_bal                3.212019
# revol_util              -0.027564
# total_acc                0.832481
# pub_rec_bankruptcies     1.409231
# dtype: float64

# %% [markdown]
# > loan amount

# %%
# information
df_columns[df_columns['column']=='loan_amnt']
# Out:
#        column  \
# 41  loan_amnt
#
#                                                                                                                                                               column_description
# 41  The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %%
# quantile test
df['loan_amnt'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('loan_amnt')

# %%
# value distributions
df['loan_amnt'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# skewness and kurtosis test
df['loan_amnt'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('loan_amnt')
# Out:
# mean: 10408.1
# median: 9250.0
# mode: 10000

# %% [markdown]
# ##### Notes:
# * Most loan amounts are small values.

# %% [markdown]
# > term

# %%
# information
df_columns[df_columns['column']=='term']
# Out:
#    column  \
# 94   term
#
#                                                                       column_description
# 94  The number of payments on the loan. Values are in months and can be either 36 or 60.

# %%
# value distributions
df['term'].value_counts().plot(kind='barh',figsize=(30,10))
plt.show()

# %%
# plot
df['term'].value_counts().plot(kind='pie',figsize=(5,5))
plt.show()

# %% [markdown]
# > interest rate

# %%
# information
df_columns[df_columns['column']=='int_rate']
# Out:
#       column         column_description
# 34  int_rate  Interest Rate on the loan

# %%
# quantile test
df['int_rate'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('int_rate')

# %%
# value distributions
df['int_rate'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['int_rate'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('int_rate')
# Out:
# mean: 11.8
# median: 11.71
# mode: 10.99

# %% [markdown]
# > installment

# %%
# information
df_columns[df_columns['column']=='installment']
# Out:
#          column  \
# 33  installment
#
#                                                   column_description
# 33  The monthly payment owed by the borrower if the loan originates.

# %%
# quantile test
df['installment'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('installment')

# %%
# value distributions
df['installment'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['installment'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('installment')
# Out:
# mean: 290.16
# median: 262.76
# mode: 311.11

# %% [markdown]
# > grade

# %%
# information
df_columns[df_columns['column']=='grade']
# Out:
#    column      column_description
# 25  grade  LC assigned loan grade

# %%
# value distributions
df['grade'].value_counts().plot(kind='barh',figsize=(30,10))
plt.show()

# %%
# plot
df['grade'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > employement length

# %%
# information
df_columns[df_columns['column']=='emp_length']
# Out:
#         column  \
# 19  emp_length
#
#                                                                                                                     column_description
# 19  Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
# value distributions
df['emp_length'].value_counts().plot(kind='barh',figsize=(30,10))
plt.show()

# %%
# plot
df['emp_length'].value_counts().plot(kind='pie',figsize=(5,5))
plt.show()

# %% [markdown]
# > home ownership

# %%
# information
df_columns[df_columns['column']=='home_ownership']
# Out:
#             column  \
# 26  home_ownership
#
#                                                                                                      column_description
# 26  The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.

# %%
# value distributions
df['home_ownership'].value_counts().plot(kind='barh',figsize=(30,10))
plt.show()

# %%
# plot
df['home_ownership'].value_counts().plot(kind='pie',figsize=(5,5))
plt.show()

# %% [markdown]
# > annual income

# %%
# information
df_columns[df_columns['column']=='annual_inc']
# Out:
#        column  \
# 4  annual_inc
#
#                                                               column_description
# 4  The self-reported annual income provided by the borrower during registration.

# %%
# quantile test
df['annual_inc'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('annual_inc')

# %%
# value distributions
df['annual_inc'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['annual_inc'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('annual_inc')
# Out:
# mean: 58957.67
# median: 55000.0
# mode: 60000.0

# %% [markdown]
# > verificaiton status

# %%
# information
df_columns[df_columns['column']=='verification_status']
# Out:
#                   column  \
# 112  verification_status
#
#                                                                              column_description
# 112  Indicates if income was verified by LC, not verified, or if the income source was verified

# %%
# value distributions
df['verification_status'].value_counts().plot(kind='barh',figsize=(30,10))
plt.show()

# %%
# plot
df['verification_status'].value_counts().plot(kind='pie',figsize=(5,5))
plt.show()

# %% [markdown]
# > issue date

# %%
# information
df_columns[df_columns['column']=='issue_d']
# Out:
#      column                   column_description
# 35  issue_d  The month which the loan was funded

# %%
# value distributions
pd.DatetimeIndex(df['issue_d']).year.value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %%
# value distributions
# value distributions
pd.DatetimeIndex(df['issue_d']).year.value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['issue_d'].value_counts().plot(kind='kde',figsize=(30,10))
plt.show()

# %% [markdown]
# > purpose

# %%
# information
df_columns[df_columns['column']=='purpose']
# Out:
#      column                                          column_description
# 87  purpose  A category provided by the borrower for the loan request.

# %%
# value distributions
df['purpose'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['purpose'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > zipcode

# %%
# information
df_columns[df_columns['column']=='zip_code']
# Out:
#        column  \
# 114  zip_code
#
#                                                                         column_description
# 114  The first 3 numbers of the zip code provided by the borrower in the loan application.

# %%
# value distributions
df['zip_code'].value_counts()[:5]
# Out:
# 945    472
# 112    461
# 100    459
# 606    450
# 70     400
# Name: zip_code, dtype: int64

# %% [markdown]
# > state

# %%
# information
df_columns[df_columns['column']=='addr_state']
# Out:
#        column                                          column_description
# 2  addr_state  The state provided by the borrower in the loan application

# %%
# value distributions
df['addr_state'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['addr_state'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > dti

# %%
# information
df_columns[df_columns['column']=='dti']
# Out:
#    column  \
# 16    dti
#
#                                                                                                                                                                                           column_description
# 16  A ratio calculated using the borrower�s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower�s self-reported monthly income.

# %%
# quantile test
df['dti'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('dti')

# %%
# value distributions
df['dti'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['dti'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('dti')
# Out:
# mean: 13.42
# median: 13.52
# mode: 0.0

# %% [markdown]
# > borrower delinquency for past 2 years

# %%
# information
df_columns[df_columns['column']=='delinq_2yrs']
# Out:
#          column  \
# 13  delinq_2yrs
#
#                                                                                               column_description
# 13  The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years

# %%
# plot
df['delinq_2yrs'].value_counts().plot(kind='barh',figsize=(25,10))
plt.show()

# %%
# value distributions
df['delinq_2yrs'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > earlierst credit line date

# %%
# information
df_columns[df_columns['column']=='earliest_cr_line']
# Out:
#               column  \
# 18  earliest_cr_line
#
#                                                    column_description
# 18  The month the borrower's earliest reported credit line was opened

# %%
# value distributions
pd.DatetimeIndex(df['earliest_cr_line']).year.value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
pd.DatetimeIndex(df['earliest_cr_line']).year.value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > borrower inquiries in last 6 months

# %%
# information
df_columns[df_columns['column']=='inq_last_6mths']

# %%
# value distributions
df['inq_last_6mths'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['inq_last_6mths'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > open account

# %%
# information
df_columns[df_columns['column']=='open_acc']

# %%
# value distributions
df['open_acc'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['grade'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > derogatory public records

# %%
# information
df_columns[df_columns['column']=='pub_rec']

# %%
# value distributions
df['pub_rec'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['pub_rec'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > revolving balance

# %%
# information
df_columns[df_columns['column']=='revol_bal']

# %%
# quantile test
df['revol_bal'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('revol_bal')

# %%
# value distributions
df['revol_bal'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['revol_bal'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('revol_bal')

# %% [markdown]
# > revolving credit utilisation

# %%
# information
df_columns[df_columns['column']=='revol_util']

# %%
# quantile test
df['revol_util'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('revol_util')

# %%
# value distributions
df['revol_util'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['revol_util'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('revol_util')

# %% [markdown]
# > total credit accounts

# %%
# information
df_columns[df_columns['column']=='total_acc']

# %%
# quantile test
df['total_acc'].plot(kind='box',vert=False,figsize=(30,10))
plt.show()

# %%
# remove outliers
remove_outliers('total_acc')

# %%
# value distributions
df['total_acc'].plot(kind='hist',bins=100,figsize=(30,10))
plt.show()

# %%
# kurtosis test
df['total_acc'].plot(kind='kde',figsize=(30,10))
plt.show()

# %%
column_statistics('total_acc')

# %% [markdown]
# > last credit pulled date

# %%
# information
df_columns[df_columns['column']=='last_credit_pull_d']

# %%
# value distributions
pd.DatetimeIndex(df['last_credit_pull_d']).year.value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
pd.DatetimeIndex(df['last_credit_pull_d']).year.value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# > publicly recorded bankruptcies

# %%
# information
df_columns[df_columns['column']=='pub_rec_bankruptcies']

# %%
# value distributions
df['pub_rec_bankruptcies'].value_counts().plot(kind='bar',figsize=(30,10))
plt.show()

# %%
# value distributions
df['pub_rec_bankruptcies'].value_counts().plot(kind='pie',figsize=(7,7))
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# available columns, except target columns 'loan status'
df.loc[:,df.columns!='loan_status'].columns

# %%
# feature variable set  --> add columns name, if relation identified
feature_variable = set()

# %% [markdown]
# ### Target Variable = > loan_status
# ##### vs
# ###  Variable (Feature Selection)

# %% [markdown]
# > loan amount

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='loan_amnt',y='loan_status',data=df)
sns.boxplot(x='loan_amnt',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='loan_amnt', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["loan_amnt"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at low loan amount.
# * inference - customers are more intended to default -- in lower loan amount.
# * feature selection - positive

# %%
# add to feature variable
feature_variable.add('loan_amnt')

# %% [markdown]
# > term

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='term',y='loan_status',data=df)
sns.boxplot(x='term',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='term', hue='loan_status',data=df)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["term"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - in higher term, proportion of default customer are more.
# * inference - customers are more intended to default -- with higher term.
# * feature selection - positive

# %%
# add to feature variables
feature_variable.add('term')

# %% [markdown]
# > interest rate

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='int_rate',y='loan_status',data=df)
sns.boxplot(x='int_rate',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='int_rate', hue='loan_status',multiple="stack",data=df,kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["int_rate"]
sns.displot(x=value, data=df,kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - higher interest rate are more likelt to default.
# * inference - customers are more intended to default -- in higher interest rate.
# * feature selection - positive

# %%
# add to feature variables
feature_variable.add('int_rate')

# %% [markdown]
# > installment

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='installment',y='loan_status',data=df)
sns.boxplot(x='installment',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='installment', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["installment"]
sns.displot(x=value, data=df,kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at low installment.
# * inference - customers are more intended to default -- in lower installment.
# * already covered with loan amount, term and interest rate.
# * feature selection - negative

# %% [markdown]
# > grade

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='grade',hue='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='grade', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['grade'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - middle level grades are more likely tp default.
# * inference - customers are more intended to default -- borrowers graded as (A,B,C,D).
# * feature selection - negative

# %% [markdown]
# > borrower employement length

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='emp_length',y='loan_status',data=df)
sns.boxplot(x='emp_length',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='emp_length', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["emp_length"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at low and very high employement length. very high employement length is accumulation of data, so can be avoided.
# * inference - customers are more intended to default -- in lower employement length.
# * feature selection - negative

# %%
# add to feature variables
feature_variable.add('emp_length')

# %% [markdown]
# > home ownership

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='home_ownership',hue='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='home_ownership', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['home_ownership'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - borrower with rental stay aremore likely to default.
# * inference - customers are more intended to default -- rental stay.
# * feature selection - negative

# %% [markdown]
# > annual income

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='annual_inc',y='loan_status',data=df)
sns.boxplot(x='annual_inc',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='annual_inc', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["annual_inc"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at low income.
# * inference - customers are more intended to default -- in lower income.
# * feature selection - positive

# %%
# add to feature variable list
feature_variable.add('annual_inc')

# %% [markdown]
# > verification status

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='verification_status',hue='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='verification_status', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['verification_status'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - non-verified customers have higher default rate
# * inference - customers are more intended to default- non-verified.
# * feature selection - positive

# %%
# add to feature variable list
feature_variable.add('verification_status')

# %% [markdown]
# > issue date(year)

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x=pd.DatetimeIndex(df['issue_d']).year,y='loan_status',data=df)
sns.boxplot(x=pd.DatetimeIndex(df['issue_d']).year,y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x=pd.DatetimeIndex(df['issue_d']).year, hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=pd.DatetimeIndex(df['issue_d']).year
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at recent years.
# * inference - customers are more intended to default -- recent customers.
# * feature selection - negative

# %% [markdown]
# > loan purpose

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(x='purpose',hue='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='purpose', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['purpose'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate at 'debt consildation' loan purpose.
# * inference - customers are more intended to default -- for purpose is 'debt consolidation'
# * feature selection - positive

# %%
# add to feature variable list
feature_variable.add('purpose')

# %% [markdown]
# > zipcode

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='zip_code',y='loan_status',data=df)
sns.boxplot(x='zip_code',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='zip_code', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["zip_code"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - at some address.
# * inference - customers are more intended to default -- in selected zipcodes.
# * feature selection - negatives. will be covered ins states.

# %% [markdown]
# > state

# %%
# distribution plot
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='addr_state', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['addr_state'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(20,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - some states have very high default rates.
# * inference - customers are more intended to default -- borrowers from CA, CH.
# * feature selection -

# %%
# add to feature variable list
feature_variable.add('addr_state')

# %% [markdown]
# > dti score

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='dti',y='loan_status',data=df)
sns.boxplot(x='dti',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='dti', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["dti"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - at moderate dti score.
# * inference - customers are more intended to default -- in mean dti score.
# * feature selection - poisitve

# %%
# add to feature variable list
feature_variable.add('dti')

# %% [markdown]
# > delinquency in past 2 years

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='delinq_2yrs', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["delinq_2yrs"]
sns.displot(x=value, data=df,kind="kde")
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
df['delinq_2yrs'][df['loan_status']=='Charged Off'].value_counts().plot(kind='line',figsize=(30,10))
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - borrowers with no past delinquency are defaulting.
# * inference - customers are more intended to default -- no delinquency  history
# * feature selection - negative

# %% [markdown]
# > issue date(year)

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x=pd.DatetimeIndex(df['earliest_cr_line']).year,y='loan_status',data=df)
sns.boxplot(x=pd.DatetimeIndex(df['earliest_cr_line']).year,y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x=pd.DatetimeIndex(df['earliest_cr_line']).year, hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=pd.DatetimeIndex(df['earliest_cr_line']).year
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate of borrwers first credit account in year 2000.
# * inference - customers are more intended to default -- for year 200.
# * feature selection - negative

# %% [markdown]
# > enquiries in last 6 months

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='inq_last_6mths',y='loan_status',data=df)
sns.boxplot(x='inq_last_6mths',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='inq_last_6mths', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["inq_last_6mths"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - maximum default for borrowers making no credit enquiry in last 6 months.
# * inference - customers are more intended to default -- no credit enquiry history for last 6 monthss.
# * feature selection - negative

# %% [markdown]
# > open accounts

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='open_acc',y='loan_status',data=df)
sns.boxplot(x='open_acc',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='open_acc', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["open_acc"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrower with less accounts.
# * inference - customers are more intended to default -- having very less accounts.
# * feature selection - negative

# %% [markdown]
# > derogatory public records

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='pub_rec',y='loan_status',data=df)
sns.boxplot(x='pub_rec',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='pub_rec', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["pub_rec"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrower with no past record.
# * inference - customers are more intended to default -- having no derogatory record.
# * feature selection - negative

# %% [markdown]
# > credit revolving balance

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='revol_bal',y='loan_status',data=df)
sns.boxplot(x='revol_bal',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='revol_bal', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["revol_bal"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrowe with low credit revolving balance.
# * inference - customers are more intended to default -- low credit in rotation.
# * feature selection - negative

# %% [markdown]
# > credit revolution utilization

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='revol_util',y='loan_status',data=df)
sns.boxplot(x='revol_util',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='revol_util', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["revol_util"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrowers increasing credit utilization
# * inference - customers are more intended to default -- with higher credit credit utilisation.
# * feature selection - positive.

# %%
# add to feature variable list
feature_variable.add('revol_util')

# %% [markdown]
# > total credit accounts

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='total_acc',y='loan_status',data=df)
sns.boxplot(x='total_acc',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='total_acc', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["total_acc"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrowers with low credit accounts
# * inference - customers are more intended to default -- less number of total credit accounts
# * feature selection - negative

# %% [markdown]
# > last credit pulled date(year)

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x=pd.DatetimeIndex(df['last_credit_pull_d']).year,y='loan_status',data=df)
sns.boxplot(x=pd.DatetimeIndex(df['last_credit_pull_d']).year,y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x=pd.DatetimeIndex(df['last_credit_pull_d']).year, hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=pd.DatetimeIndex(df['last_credit_pull_d']).year
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate of borrwers with recent credit report pulled.
# * inference - customers are more intended to default -- recent credit enquiry.
# * feature selection - negative

# %% [markdown]
# > public record bankruptcies

# %%
# relational plot
fig, ax = plt.subplots(figsize=(20,10))
sns.violinplot(x='pub_rec_bankruptcies',y='loan_status',data=df)
sns.boxplot(x='pub_rec_bankruptcies',y='loan_status',data=df)
plt.show()

# %%
# distribution plot of feature variable with target variable
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(x='pub_rec_bankruptcies', hue='loan_status',multiple="stack",data=df, kde=True)
plt.show()

# %%
# proportion plot of feature variable with target variable value 'charged off'
value=df[df["loan_status"]=='Charged Off']["pub_rec_bankruptcies"]
sns.displot(x=value, data=df, kind="kde")
plt.show()

# %% [markdown]
# ##### Notes:
# * analysis - high default rate  - borrowers with public record bankruptcies
# * inference - customers are more intended to default -- no past records
# * feature selection - negative

# %% [markdown]
# ## Multivariate Anlysis

# %%
# feature selected
print(feature_variable)
